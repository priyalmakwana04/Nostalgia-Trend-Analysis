# %%
import pandas as pd
import os

df = pd.read_csv("../data/clustered_data.csv")  # use clustered one for dashboard

out_path = "../powerbi/powerbi_ready_data.csv"
df.to_csv(out_path, index=False)

print("✅ Exported for Power BI:", out_path)
print("File exists?", os.path.exists(out_path))
# Out:
# ✅ Exported for Power BI: ../powerbi/powerbi_ready_data.csv
# File exists? True
